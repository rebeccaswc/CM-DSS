# %% [markdown]
# ### 🚀 **套件安裝**

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: datasets in ./.venv/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (2.21.0)
# Requirement already satisfied: numpy>=1.23.2 in ./.venv/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: scipy>=1.6.0 in ./.venv/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: filelock in ./.venv/lib/python3.11/site-packages (from datasets->-r requirements.txt (line 3)) (3.15.4)
# Requirement already satisfied: pyarrow>=15.0.0 in ./.venv/lib/python3.11/site-packages (from datasets->-r requirements.txt (line 3)) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in ./.venv/lib/python3.11/site-packages (from datasets->-r requirements.txt (line 3)) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in ./.venv/lib/python3.11/site-packages (from datasets->-r requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in ./.venv/lib/python3.11/site-packages (from datasets->-r requirements.txt (line 3)) (4.66.5)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.11/site-packages (from datasets->-r requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.11/site-packages (from datasets->-r requirements.txt (line 3)) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.6.1,>=2023.1.0 in ./.venv/lib/python3.11/site-packages (from datasets->-r requirements.txt (line 3)) (2024.6.1)
# Requirement already satisfied: aiohttp in ./.venv/lib/python3.11/site-packages (from datasets->-r requirements.txt (line 3)) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in ./.venv/lib/python3.11/site-packages (from datasets->-r requirements.txt (line 3)) (0.24.6)
# Requirement already satisfied: packaging in ./.venv/lib/python3.11/site-packages (from datasets->-r requirements.txt (line 3)) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.11/site-packages (from datasets->-r requirements.txt (line 3)) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./.venv/lib/python3.11/site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.11/site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.11/site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.11/site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.11/site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.11/site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (1.9.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.venv/lib/python3.11/site-packages (from huggingface-hub>=0.21.2->datasets->-r requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 3)) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 3)) (2024.8.30)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import re
from datasets import load_dataset

# %% [markdown]
# ### 🚀 **Read Data**

# %%
ds = load_dataset("Ajayk/Alerts-data-desc")

# 劃分訓練與測試集
# train_ds = ds['train']
# test_ds = ds['test']
# train_df = ds.to_pandas()

# 將 train & test set 合併
total_df = pd.concat([pd.DataFrame(ds[split]) for split in ds.keys()])

# %% [markdown]
# ### 🚀 **Data Overviewing**

# %%
# 查看 "Ajayk/Alerts-data-desc" 結構
print(ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['log', 'target', 'description'],
#         num_rows: 8000
#     })
#     test: Dataset({
#         features: ['log', 'target', 'description'],
#         num_rows: 2000
#     })
# })

# %%
total_df .head()
# Out:
#                                                  log              target  \
# 0  full_log:Apr 11 14:04:27 ssdnodes-652a982af37b...      False Positive
# 1  full_log:Apr 11 20:21:42 ssdnodes-652a982af37b...  Not-False Positive
# 2  full_log:Apr 11 13:14:02 ssdnodes-652a982af37b...      False Positive
# 3  full_log:Apr 11 11:45:01 ssdnodes-652a982af37b...  Not-False Positive
# 4  full_log:Apr 11 14:17:02 ssdnodes-652a982af37b...      False Positive
#
#                                          description
# 0  The input alert log data indicates a failed lo...
# 1  The input log data is an alert log from a secu...
# 2  The alert log data indicates an invalid user a...
# 3  The input alert log data indicates a failed pa...
# 4  The alert log data indicates an invalid user a...

# %%
# 查看 total_df 的行列數
print(total_df.shape)
# Out:
# (10000, 3)

# %% [markdown]
# ### 🚀 **Log extraction**

# %%
# 通用的 Extract function
def extract_with_pattern(log, pattern, group_index=1):
    match = re.search(pattern, log)
    return match.group(group_index) if match else None

# %%
# Extract IP
def extract_ip(log):
        match = re.search(r'\d{1,3}(?:\.\d{1,3}){3}' ,log)
        if not match:
                return False
        ip = match.group()
        return ip if is_valid_ip(ip) else None

# 確認 IP 是否符合 IPv4 規範(0 到 255範圍內)
def is_valid_ip(ip):
        return all(0 <= int(part) <= 255 for part in ip.split('.'))

# Extract time
def extract_timestamp(log):
        pattern = r'(\w{3}\s\d{1,2},\s\d{4})\s@\s(\d{2}:\d{2}:\d{2})\.(\d{3})'
        match = re.search(pattern,log)
        if match:
                return f'{match.group(1)} {match.group(2)}'
        return None

# Extract port
def extract_port(log):
        pattern = r'port(\s\d{1,5})'
        return extract_with_pattern(log, pattern)

# Extract Country
def extract_country(log):
        pattern =  r'country_name:\s*(?!\[)([^,\[]+)'
        return extract_with_pattern(log, pattern)


# Extract Longitude(經度)
def extract_longitude(log):
        pattern = r'lon:(-?\d+\.\d+)'
        return extract_with_pattern(log, pattern)

# Extract Latitude(緯度)
def extract_latitude(log):
        pattern = r'lat:(-?\d+\.\d+)'
        return extract_with_pattern(log, pattern)


################## Rule Information ##################

# Extract rule ID -> 事件唯一識別碼？
def extract_rule_id(log):
    pattern = r'rule\\.id:(\d+)'
    return extract_with_pattern(log, pattern)

# Extract rule level -> 事件嚴重性
def extract_rule_level(log):
    pattern = r'rule\\.level:(\d+)'
    return extract_with_pattern(log, pattern)

# Extract rule mail -> 是否有用 mail 通知
def extract_rule_mail(log):
    pattern = r'rule\\.mail:(True|False)'
    return extract_with_pattern(log, pattern)

# Extract rule description
def extract_rule_description(log):
        pattern = r'rule\\.description:sshd:\s*([^,]*)'
        return extract_with_pattern(log, pattern)

# Extract rule group
def extract_rule_groups(log):
        pattern = r'rule\\.groups:(\[\s*.*?\s*\])'
        return extract_with_pattern(log, pattern)

# Extract rule firedtimes -> 規則觸發次數
def extract_ruel_firedtimes(log):
    pattern = r'firedtimes:\s*([^,]*)'
    return extract_with_pattern(log, pattern)

#######################################################

# MITRE ATT&CK

def extract_mitre_technique(log):
    pattern = r'mitre\\.technique:(\[\s*.*?\s*\])'
    return extract_with_pattern(log, pattern)

def extract_mitre_id(log):
    pattern = r'mitre\\.id:(\[\s*.*?\s*\])'
    return extract_with_pattern(log, pattern)

def extract_mitre_tactic(log):
    pattern = r'mitre\\.tactic:(\[\s*.*?\s*\])'
    return extract_with_pattern(log, pattern)

# 美國 NIST 資安法規
def extract_nist(log):
        pattern = r'nist_800_53:(\[\s*.*?\s*\])'
        return extract_with_pattern(log, pattern)

# GDPR(一般資料保護規則)
def extract_gdpr(log): 
        pattern = r'gdpr:(\[\s*.*?\s*\])'
        return extract_with_pattern(log, pattern)

# GPG13(UK Government's Good Practice Guide 13) 
def extract_gpg13(log): 
        pattern = r'gpg13:(\[\s*.*?\s*\])'
        return extract_with_pattern(log, pattern)

# HIPAA
def extract_hipaa(log):
    pattern = r'hipaa:(\[\s*.*?\s*\])'
    return extract_with_pattern(log, pattern)

# TSC
def extract_tsc(log):
    pattern = r'tsc:(\[\s*.*?\s*\])'
    return extract_with_pattern(log, pattern)

# PCI DSS
def extract_pci_dss(log):
    pattern = r'pci_dss:(\[\s*.*?\s*\])'
    return extract_with_pattern(log, pattern)

# # Extract synopsis
# def extract_synopsis(log):
#         pattern = r'sshd\[\d+\]:\s*(.*)(?=,)'
#         return extract_with_pattern(log, pattern)

# %%
def extract_features(log):
    return {
        'Source IP': extract_ip(log),
        'Timestamp': extract_timestamp(log),
        'Port': extract_port(log),
        'Country': extract_country(log),
        'Longitude': extract_longitude(log),
        'Latitude': extract_latitude(log),
        'Rule ID': extract_rule_id(log),
        'Rule Level': extract_rule_level(log),
        'Rule Description': extract_rule_description(log),
        'Rule Groups': extract_rule_groups(log),
        'Rule Mail': extract_rule_mail(log),
        'MITRE Technique': extract_mitre_technique(log),
        'MITRE ID': extract_mitre_id(log),
        'MITRE Tactic': extract_mitre_tactic(log),
        'Nist 800-53': extract_nist(log),
        'GDPR': extract_gdpr(log),
        'GPG13': extract_gpg13(log),
        'HIPAA': extract_hipaa(log),
        'TSC': extract_tsc(log),
        'PCI DSS': extract_pci_dss(log),
        'Firedtimes': extract_ruel_firedtimes(log),
    }

features_df = total_df['log'].apply(extract_features).apply(pd.Series)
total_df = pd.concat([total_df, features_df], axis=1)
total_df.head()
# Out:
#                                                  log              target  \
# 0  full_log:Apr 11 14:04:27 ssdnodes-652a982af37b...      False Positive
# 1  full_log:Apr 11 20:21:42 ssdnodes-652a982af37b...  Not-False Positive
# 2  full_log:Apr 11 13:14:02 ssdnodes-652a982af37b...      False Positive
# 3  full_log:Apr 11 11:45:01 ssdnodes-652a982af37b...  Not-False Positive
# 4  full_log:Apr 11 14:17:02 ssdnodes-652a982af37b...      False Positive
#
#                                          description        Source IP  \
# 0  The input alert log data indicates a failed lo...   170.64.161.109
# 1  The input log data is an alert log from a secu...    170.64.233.19
# 2  The alert log data indicates an invalid user a...  104.225.217.122
# 3  The input alert log data indicates a failed pa...   180.101.88.229
# 4  The alert log data indicates an invalid user a...  104.225.217.122
#
#                Timestamp    Port        Country  Longitude Latitude Rule ID  \
# 0  Apr 11, 2024 14:04:29   57684  United States    -97.822   37.751    5710
# 1  Apr 11, 2024 20:21:42   35662           None       None     None    None
# 2  Apr 11, 2024 13:14:02   35482  United States  -122.3447  47.6144    5710
# 3  Apr 11, 2024 11:45:03   49145          China   121.4012  31.0449    5760
# 4  Apr 11, 2024 14:17:04   59630  United States  -122.3447  47.6144    5710
#
#    ...              MITRE Technique                   MITRE ID  \
# 0  ...  ["Password Guessing","SSH"]  ["T1110.001","T1021.004"]
# 1  ...                         None                    ["7.1"]
# 2  ...  ["Password Guessing","SSH"]  ["T1110.001","T1021.004"]
# 3  ...  ["Password Guessing","SSH"]  ["T1110.001","T1021.004"]
# 4  ...  ["Password Guessing","SSH"]  ["T1110.001","T1021.004"]
#
#                                         MITRE Tactic              Nist 800-53  \
# 0           ["Credential Access","Lateral Movement"]  ["AU.14","AC.7","AU.6"]
# 1  ["syslog","sshd","authentication_failed","inva...                     None
# 2           ["Credential Access","Lateral Movement"]  ["AU.14","AC.7","AU.6"]
# 3           ["Credential Access","Lateral Movement"]         ["AU.14","AC.7"]
# 4           ["Credential Access","Lateral Movement"]  ["AU.14","AC.7","AU.6"]
#
#                       GDPR    GPG13          HIPAA  \
# 0  ["IV_35.7.d","IV_32.2"]  ["7.1"]  ["164.312.b"]
# 1                     None     None           None
# 2  ["IV_35.7.d","IV_32.2"]  ["7.1"]  ["164.312.b"]
# 3  ["IV_35.7.d","IV_32.2"]  ["7.1"]  ["164.312.b"]
# 4  ["IV_35.7.d","IV_32.2"]  ["7.1"]  ["164.312.b"]
#
#                                  TSC                       PCI DSS Firedtimes
# 0  ["CC6.1","CC6.8","CC7.2","CC7.3"]  ["10.2.4","10.2.5","10.6.1"]        349
# 1                               None                 ["164.312.b"]        log
# 2  ["CC6.1","CC6.8","CC7.2","CC7.3"]  ["10.2.4","10.2.5","10.6.1"]        318
# 3  ["CC6.1","CC6.8","CC7.2","CC7.3"]           ["10.2.4","10.2.5"]        457
# 4  ["CC6.1","CC6.8","CC7.2","CC7.3"]  ["10.2.4","10.2.5","10.6.1"]       1058
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 🚀 **確認空值**

# %%
empty_source_ip_rows = total_df[total_df['Source IP'].isna()]
empty_timestamp_rows = total_df[total_df['Timestamp'].isna()]
empty_port_rows = total_df[total_df['Port'].isna()]
empty_rule_id_rows = total_df[total_df['Port'].isna()]

# %%
total_df.isna().sum()
# Out:
# log                    0
# target                 0
# description            0
# Source IP              3
# Timestamp              0
# Port                3832
# Country             3643
# Longitude           4165
# Latitude            4165
# Rule ID             3650
# Rule Level             0
# Rule Description    6080
# Rule Groups         3650
# Rule Mail           5000
# MITRE Technique     3816
# MITRE ID             219
# MITRE Tactic         166
# Nist 800-53         3680
# GDPR                3665
# GPG13               3770
# HIPAA               3680
# TSC                 3680
# PCI DSS               19
# Firedtimes             0
# dtype: int64

# %% [markdown]
# ### 🚀 **數據預處理**

# %%
total_df = total_df[total_df['Firedtimes'] != 'log']
total_df = total_df.reset_index(drop=True)
total_df.head()
# Out:
#                                                  log              target  \
# 0  full_log:Apr 11 14:04:27 ssdnodes-652a982af37b...      False Positive
# 1  full_log:Apr 11 13:14:02 ssdnodes-652a982af37b...      False Positive
# 2  full_log:Apr 11 11:45:01 ssdnodes-652a982af37b...  Not-False Positive
# 3  full_log:Apr 11 14:17:02 ssdnodes-652a982af37b...      False Positive
# 4  full_log:Apr 11 12:35:51 ssdnodes-652a982af37b...  Not-False Positive
#
#                                          description        Source IP  \
# 0  The input alert log data indicates a failed lo...   170.64.161.109
# 1  The alert log data indicates an invalid user a...  104.225.217.122
# 2  The input alert log data indicates a failed pa...   180.101.88.229
# 3  The alert log data indicates an invalid user a...  104.225.217.122
# 4  The alert log data indicates a failed password...   180.101.88.229
#
#                Timestamp    Port        Country  Longitude Latitude Rule ID  \
# 0  Apr 11, 2024 14:04:29   57684  United States    -97.822   37.751    5710
# 1  Apr 11, 2024 13:14:02   35482  United States  -122.3447  47.6144    5710
# 2  Apr 11, 2024 11:45:03   49145          China   121.4012  31.0449    5760
# 3  Apr 11, 2024 14:17:04   59630  United States  -122.3447  47.6144    5710
# 4  Apr 11, 2024 12:35:53   60218          China   121.4012  31.0449    5760
#
#    ...              MITRE Technique                   MITRE ID  \
# 0  ...  ["Password Guessing","SSH"]  ["T1110.001","T1021.004"]
# 1  ...  ["Password Guessing","SSH"]  ["T1110.001","T1021.004"]
# 2  ...  ["Password Guessing","SSH"]  ["T1110.001","T1021.004"]
# 3  ...  ["Password Guessing","SSH"]  ["T1110.001","T1021.004"]
# 4  ...  ["Password Guessing","SSH"]  ["T1110.001","T1021.004"]
#
#                                MITRE Tactic              Nist 800-53  \
# 0  ["Credential Access","Lateral Movement"]  ["AU.14","AC.7","AU.6"]
# 1  ["Credential Access","Lateral Movement"]  ["AU.14","AC.7","AU.6"]
# 2  ["Credential Access","Lateral Movement"]         ["AU.14","AC.7"]
# 3  ["Credential Access","Lateral Movement"]  ["AU.14","AC.7","AU.6"]
# 4  ["Credential Access","Lateral Movement"]         ["AU.14","AC.7"]
#
#                       GDPR    GPG13          HIPAA  \
# 0  ["IV_35.7.d","IV_32.2"]  ["7.1"]  ["164.312.b"]
# 1  ["IV_35.7.d","IV_32.2"]  ["7.1"]  ["164.312.b"]
# 2  ["IV_35.7.d","IV_32.2"]  ["7.1"]  ["164.312.b"]
# 3  ["IV_35.7.d","IV_32.2"]  ["7.1"]  ["164.312.b"]
# 4  ["IV_35.7.d","IV_32.2"]  ["7.1"]  ["164.312.b"]
#
#                                  TSC                       PCI DSS Firedtimes
# 0  ["CC6.1","CC6.8","CC7.2","CC7.3"]  ["10.2.4","10.2.5","10.6.1"]        349
# 1  ["CC6.1","CC6.8","CC7.2","CC7.3"]  ["10.2.4","10.2.5","10.6.1"]        318
# 2  ["CC6.1","CC6.8","CC7.2","CC7.3"]           ["10.2.4","10.2.5"]        457
# 3  ["CC6.1","CC6.8","CC7.2","CC7.3"]  ["10.2.4","10.2.5","10.6.1"]       1058
# 4  ["CC6.1","CC6.8","CC7.2","CC7.3"]           ["10.2.4","10.2.5"]        328
#
# [5 rows x 24 columns]

# %%
# 儲存 csv 檔案
total_df.to_csv('alert_data.csv', index=True)

# %%
# 總行列數
total_df.shape
# Out:
# (6350, 24)
